# %%
my_dict={'a':1,'b':2,'c':{'d':3,'f':{'g':4,'h':5,'i':{'name':'besant'},'j':6},'k':7},'m':8}
my_dict['c']
# Out:
# {'d': 3, 'f': {'g': 4, 'h': 5, 'i': {'name': 'besant'}, 'j': 6}, 'k': 7}

# %%
my_dict['c']['f']['i']
# Out:
# {'name': 'besant'}

# %%
my_dict['c']['f']['i']['name']="Poornima"

# %%
my_dict
# Out:
# {'a': 1,
#  'b': 2,
#  'c': {'d': 3,
#   'f': {'g': 4, 'h': 5, 'i': {'name': 'Poornima'}, 'j': 6},
#   'k': 7},
#  'm': 8}
